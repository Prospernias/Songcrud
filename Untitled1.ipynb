# %% [markdown]
# <a href="https://colab.research.google.com/github/Prospernias/Songcrud/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/hotel_bookings.csv")

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81537 entries, 0 to 81536
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           81537 non-null  object
#  1   is_canceled                     81537 non-null  int64
#  2   lead_time                       81537 non-null  int64
#  3   arrival_date_year               81537 non-null  int64
#  4   arrival_date_month              81537 non-null  object
#  5   arrival_date_week_number        81537 non-null  int64
#  6   arrival_date_day_of_month       81537 non-null  int64
#  7   stays_in_weekend_nights         81537 non-null  int64
#  8   stays_in_week_nights            81537 non-null  int64
#  9   adults                          81537 non-null  int64
#  10  children                        81533 non-null  float64
#  11  babies                          81537 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             487
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df.dropna().shape
# Out:
# (184, 32)

# %%
df2 = df.drop(["company"], axis = 1)

# %%
df2.dropna(inplace = True)

# %%
df2.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
numerical_df = df2.select_dtypes(include = [int, float])

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69325 entries, 3 to 81536
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   is_canceled                     69325 non-null  int64
#  1   lead_time                       69325 non-null  int64
#  2   arrival_date_year               69325 non-null  int64
#  3   arrival_date_week_number        69325 non-null  int64
#  4   arrival_date_day_of_month       69325 non-null  int64
#  5   stays_in_weekend_nights         69325 non-null  int64
#  6   stays_in_week_nights            69325 non-null  int64
#  7   adults                          69325 non-null  int64
#  8   children                        69325 non-null  float64
#  9   babies                          69325 non-null  int64
#  10  is_repeated_guest               69325 non-null  int64
#  11  previous_cancellations          69325 non-null  int64
# ...

# %%
categorical = df2.select_dtypes(exclude = [int, float])

# %%
categorical.describe()
# Out:
#              hotel arrival_date_month   meal country market_segment  \
# count        69325              69325  69325   69325          69325
# unique           2                 12      5     150              7
# top     City Hotel             August     BB     PRT      Online TA
# freq         37612               8824  52960   31834          35150
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 69325              69325              69325
# unique                    4                  8                 10
# top                   TA/TO                  A                  A
# freq                  64101              48320              42403
#
#        deposit_type customer_type reservation_status reservation_status_date
# count         69325         69325              69325                   69325
# unique            3             4                  3                     924
# ...

# %%
sns.countplot(categorical, x = "hotel")
# Out:
# <Axes: xlabel='hotel', ylabel='count'>

# %%
sns.countplot(categorical, x = "market_segment")
plt.x
# Out:
# <Axes: xlabel='market_segment', ylabel='count'>
